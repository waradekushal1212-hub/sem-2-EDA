# %% [markdown]
# # study of pandas library
#
# # **kushal warade**
# 25070123174

# %%
#study of pandas

# %%
import pandas as pd

s = pd.Series([1,2,3,4])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# create data frame
data = {
    "name":["kushal","harsh","doreomon"],
    "marks":[90,60,92]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        name  marks
# 0    kushal     90
# 1     harsh     60
# 2  doreomon     92

# %%
# FIND THE STRUCTURE OF DATAFRAME
df.shape
# Out:
# (3, 2)

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 6

# %%
df.columns
# Out:
# Index(['name', 'marks'], dtype='object')

# %%
df.dtypes
# Out:
# name     object
# marks     int64
# dtype: object

# %%
df["name"]
# Out:
# 0      kushal
# 1       harsh
# 2    doreomon
# Name: name, dtype: object

# %%
df.loc[1]
# Out:
# name     harsh
# marks       60
# Name: 1, dtype: object

# %%
df["Grade"] = ["first class","second class","distintion"]
df
# Out:
#        name  marks        grade         Grade
# 0    kushal     90  first class   first class
# 1     harsh     60   distention  second class
# 2  doreomon     92  secondclass    distintion

# %%
# update data in data frame
# chamge marks of kushal to 88

df.loc[0,"marks"] = 88
df
# Out:
#        name  marks        grade         Grade
# 0    kushal     88  first class   first class
# 1     harsh     60   distention  second class
# 2  doreomon     92  secondclass    distintion

# %%
# deleat a coloumn
df.drop("Grade",axis=1,inplace=True)
df
# Out:
#        name  marks        grade
# 0    kushal     88  first class
# 1     harsh     60   distention
# 2  doreomon     92  secondclass

# %%
max1=df["marks"].max()
max1
# Out:
# 92

# %%
# apply codition (filterig)
# displystudents scoring more than 80

df[df["marks"]>80]
# Out:
#        name  marks        grade
# 0    kushal     88  first class
# 2  doreomon     92  secondclass
